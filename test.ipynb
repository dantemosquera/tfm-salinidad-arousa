# %% [markdown]
# test

# %%
import requests
print("¡Conectado!")
# Out:
# ¡Conectado!

# %% [markdown]
# test libs

# %%
import narwhals
import patsy
import plotly
import requests
import statsmodels
import statsmodels.api as sm

print("✅ Todo perfecto: Todas las librerías están listas para usarse.")
# Out:
# ✅ Todo perfecto: Todas las librerías están listas para usarse.
